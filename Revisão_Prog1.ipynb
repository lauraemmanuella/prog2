# %% [markdown]
# <a href="https://colab.research.google.com/github/lauraemmanuella/prog2/blob/main/Revis%C3%A3o_Prog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Revisão de programação computacional 1
#
# 1. Estruturas sequenciais
# 2. Estruturas condicionais
# 3. Estruturas de repetição
# 4. Listas
# 5. Dicionários
# 6. Funções

# %% [markdown]
# ##1. Estrutura sequencial
#
# Revisar a estrutura sequencial básica de um código em Python:
# * Entrada de dados via teclado
# * Processamento (operações aritméticas, relacionais e/ou lógicas)
# * Saída de dados em tela

# %% [markdown]
# **Questão 1:** Escreva uma expressão que será utilizada para decidir se um aluno foi ou não aprovado em uma disciplina. Para ser aprovado, a média do aluno deve ser maior ou igual a 7, ou a média deve ser maior ou igual a 5 e o percentual de faltas menor que 50%.
#
# Receba 3 notas referentes às avaliações da disciplina e o percentual de faltas como entrada. Calcule a média ponderada com pesos 4, 5 e 6 (como mostrado a seguir) e mostre se aprovado é `True ou False`, como no exemplo de execução abaixo:
#
# > `media = (nota1 * 4 + nota2 * 5 + nota3 * 6) / 15`

# %%
#Seu código aqui
# Out:
# Informe a nota da primeira avaliação (entre 0 e 10): 5
# Informe a nota da segunda avaliação (entre 0 e 10): 6.5
# Informe a nota da terceira avaliação (entre 0 e 10): 4.5
# Informe o percentual de faltas na disciplina (entre 0-1): 0.45
# Média ponderada: 5.3
# Aprovado: True

# %% [markdown]
# ##2. Estrutura condicional
#
# Revisar a estrutura condicional `(if..elif..else)`

# %% [markdown]
# **Questão 2:** O IMC – Índice de Massa Corporal é um critério da Organização Mundial de Saúde para dar uma indicação sobre a condição de peso de uma pessoa adulta.
# A fórmula é `IMC = peso (kg) / altura (m) x altura (m)`. Elabore um algoritmo que leia o peso e a altura de um adulto e mostre sua condição de acordo com as informações abaixo:
#
# > Classificação do IMC:
#
# * Menor que 18,5 - Abaixo do peso
#
# * Entre 18,5 e 24,9 - Peso normal
#
# * Entre 25 e 29,9 - Sobrepeso (acima do peso desejado)
#
# * Igual ou acima de 30 - Obesidade

# %%
#Seu código aqui
# Out:
# Informe o peso (kg): 60
# Informe a altura (m): 1.60
# IMC = 23.44
# Peso normal

# %% [markdown]
# ##3. Estrutura de repetição
#
# Revisar as estruturas de repetição `(for e while)`

# %% [markdown]
# **Questão 3:** Faça um programa que receba um número inteiro positivo e mostre todos os seus divisores, como no exemplo de execução abaixo:

# %%
#Seu código aqui
# Out:
# Informe um número natural: 20
# Os divisores de 20 são:
# 1
# 2
# 4
# 5
# 10
# 20

# %% [markdown]
# **Questão 4**: Faça um programa que mostre todos os números primos entre 2 e 9

# %%
#Seu código aqui
# Out:
# 2 é um número primo
# 3 é um número primo
# 4 = 2 * 2
# 5 é um número primo
# 6 = 2 * 3
# 7 é um número primo
# 8 = 2 * 4
# 9 = 3 * 3

# %% [markdown]
# ##4. Estrutura de dados do tipo Lista
#
# Revisar listas

# %% [markdown]
# **Questão 4:** Imprima o valor 2 da lista abaixo:

# %%
lista = [1,1, [1,2]]

# %%
#Seu código aqui
# Out:
# 2

# %% [markdown]
# **Questão 5:** Use for, split() e if para criar uma declaração que imprima as palavras que começam com 's':

# %%
st = 'Print only the words that start with s in this sentence'

# %%
#codigo aqui
# Out:
# start
# s
# sentence

# %% [markdown]
# E se fosse para printar todas as palavras com S?

# %%
#codigo aqui
# Out:
# words
# start
# s
# this
# sentence

# %% [markdown]
# **Questão 6:** Preencha uma lista com as representações em Fahrenheit da seguintes temperaturas usando compreensão de listas

# %%
celsius = [0,10,20.1,34.5]

# %%
#codigo aqui
# Out:
# [32.0, 50.0, 68.18, 94.1]

# %% [markdown]
# **Questão 7:** Use a compreensão de lista para criar uma lista de todos os números entre 1 e 50 que são divisíveis por 3.

# %%
#codigo aqui
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]

# %% [markdown]
# ##5. Estrutura de dados do tipo Dicionário
#
# Revisar dicionários

# %% [markdown]
# **Questão 8:** Faça um programa que receba o nome de um produto e mostre seu preço. A lista de produtos está no dicionário abaixo:

# %%
tabela = {
    'ALFACE': 0.45,
    'BATATA': 1.20,
    'TOMATE': 2.30,
    'CENOURA': 1.50
}

# %%
#Seu código aqui
# Out:
# Digite o nome do produto ou fim para encerrrar: tomate
# Preço 2.30
# Digite o nome do produto ou fim para encerrrar: feijão
# Produto não encontrado
# Digite o nome do produto ou fim para encerrrar: fim

# %% [markdown]
# ##6. Funções
#
# Revisar a construção de funções

# %% [markdown]
# **Questão 9:** Faça uma função que receba como parâmetro uma frase e retorne uma lista com o tamanho de cada palavra contida na frase:

# %%
frase = 'How long are the words in this phrase'

# %%
#Seu código aqui
# Out:
# [3, 4, 3, 3, 5, 2, 4, 6]
